# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
 
# Create data

#x = np.arange(255)
#y = np.arange(255)

fig=plt.figure()
a=plt.axes(projection='3d')
#for row in np.nditer(x):
 #   for column in np.nditer(y):
   #pass
N=1/20
for x in range(20):
    for y in range(20): 
        for z in range(20): 
            xx=np.array([x])
            yy=np.array([y])
            zz=np.array([z])
            cx= x*N
            cy= y*N
            cz= z*N
            a.scatter3D(xx,yy,zz,c=(cx,cy,cz))


plt.title('Cube')


plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = [3.28912855713, 3.31252670518]
y = [4.64604863545, 4.65385917898]
z = [3.95526335139, 3.96834118896]
b2 = [1,1.3]

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
line = ax.scatter(x, y ,z , c=b2, s=1500, marker='*', edgecolors='none', depthshade=0)
cb = plt.colorbar(line)

def forceUpdate(event):
    global line
    line.changed()

fig.canvas.mpl_connect('draw_event', forceUpdate)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)


# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
X = [1, 2, 3]
Y = [2, 5, 8]
Z = [6, 4, 5]
colors=["r", "b", "g"]

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')


for i in range(len(X)):
    ax.scatter(X[i], Y[i], Z[i], c=colors[i])
plt.show()

# %%
# %pylab
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
chair=io.imread("/home/cesar/Desktop/rb.jpg")
#print(chair.shape)
fig = plt.figure()
a=plt.axes(projection='3d')

xy=chair[300:493,300:493 ,:]
#print(xy.shape)
io.imshow(xy)
#print(type(xy))
#print(xy[0])
# Out:
# /home/cesar/.local/lib/python3.5/site-packages/matplotlib/backends/backend_gtk3agg.py:18: UserWarning: The Gtk3Agg backend is known to not work on Python 3.x with pycairo. Try installing cairocffi.
#   "The Gtk3Agg backend is known to not work on Python 3.x with pycairo. "
# Using matplotlib backend: GTK3Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
for x in range(300,493):
    for y in range(300,493):
        print (x, y)
        #cx=(chair[x,y,0]/255,chair[x,y,1]/255,chair[x,y,2]/255)
        #a.scatter3D(x,y,c=cx)


        
#plt.title('3d')
#plt.show()
# Out:
# 300 300
# 300 301
# 300 302
# 300 303
# 300 304
# 300 305
# 300 306
# 300 307
# 300 308
# 300 309
# 300 310
# 300 311
# 300 312
# 300 313
# 300 314
# 300 315
# 300 316
# 300 317
# 300 318
# 300 319
# 300 320
# 300 321
# 300 322
# 300 323
# 300 324
# 300 325
# 300 326
# 300 327
# 300 328
# 300 329
# 300 330
# 300 331
# 300 332
# 300 333
# 300 334
# 300 335
# 300 336
# 300 337
# 300 338
# 300 339
# 300 340
# 300 341
# 300 342
# 300 343
# 300 344
# 300 345
# 300 346
# 300 347
# 300 348
# 300 349
# 300 350
# 300 351
# 300 352
# 300 353
# 300 354
# 300 355
# 300 356
# 300 357
# 300 358
# 300 359
# 300 360
# 300 361
# 300 362
# 300 363
# 300 364
# 300 365
# 300 366
# 300 367
# 300 368
# 300 369
# 300 370
# 300 371
# 300 372
# 300 373
# 300 374
# 300 375
# 300 376
# 300 377
# 300 378
# 300 379
# 300 380
# 300 381
# 300 382
# 300 383
# 300 384
# 300 385
# 300 386
# 300 387
# 300 388
# 300 389
# 300 390
# 300 391
# 300 392
# 300 393
# 300 394
# 300 395
# 300 396
# 300 397
# 300 398
# 300 399
# ...
